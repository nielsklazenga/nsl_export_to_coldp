# %% [markdown]
# # NSL export to CoLDP

# %%
import pandas as pd
import numpy as np
import urllib.request
import re


group = 'bryophytes'

urls = {
    'bryophytes': 'https://moss.biodiversity.org.au/nsl/services/export/',
    'fungi': 'https://fungi.biodiversity.org.au/nsl/services/export/',
    'lichens': 'https://lichen.biodiversity.org.au/nsl/services/export/',
    'algae': 'https://algae.biodiversity.org.au/nsl/services/export/',
    'tracheophytes': 'https://biodiversity.org.au/nsl/services/export/'
}

urllib.request.urlretrieve(urls[group] + 'namesCsv', 'data/' + group + '/names.csv')
urllib.request.urlretrieve(urls[group] + 'taxonCsv', 'data/' + group + '/taxa.csv')

# Map Latin rank names to less wankerish English ones
ranks = {
    'genus': 'genus',
    'species': 'species',
    'familia': 'family',
    'subfamilia': 'subfamily',
    'tribus': 'tribe',
    'subtribus': 'subtribe',
    'ordo': 'order',
    'subordo': 'suborder',
    'superordo': 'superorder',
    'subspecies': 'subspecies',
    'classis': 'class',
    'subclassis': 'subclass',
    'subdivision': 'subphylum',
    'subbdivision': 'subphylum',
    'varietas': 'variety',
    'nothovarietas': 'nothovariety',
    'subvarietas': 'subvariety',
    'subgenus': 'subgenus',
    'superspecies': 'superspecies',
    'forma': 'form',
    'subforma': 'subform',
    'division': 'phylum',
    'regnum': 'kingdom',
    'special form': 'special form',
    'sectio': 'section',
    'subsectio': 'subsection',
    'series': 'series',
    'subseries': 'subseries',
    'regio': 'domain',
    '[unknown]': '[unknown]',
    '[unranked]': '[unranked]',
    '[infragenus]': '[infragenus]',
    '[infraspecies]': '[infraspecies]'
}

# %% [markdown]
# ### Names

# %%
df_names = pd.read_csv('data/' + group + '/names.csv')

# Remove excess columns
columns = [
    'scientificNameID', 
    'nameAccordingToID', 
    'taxonRank', 
    'scientificName', 
    'genericName', 
    'specificEpithet', 
    'infraspecificEpithet', 
    'scientificNameAuthorship', 
    'nomenclaturalStatus',
    'originalNameUsageID', 
    'originalNameUsage'
]

df1 = df_names[columns]

# Instance ID is in nameAccordingToID for reasons unfathomable; rename to taxonID
df1 = df1.rename(columns={'nameAccordingToID': 'taxonID'})

# Filter for names with originalNameUsage
# Replace instance IDs in originalNameUsageID with scientificNameIDs; we will not need taxonID anymore after that
df2 = df1[~df1['originalNameUsageID'].isna()].merge(df1, how='left', left_on='originalNameUsageID', right_on='taxonID')[[
    'scientificNameID_x', 
    'taxonRank_x', 
    'scientificName_x', 
    'genericName_x', 
    'specificEpithet_x', 
    'infraspecificEpithet_x', 
    'scientificNameAuthorship_x', 
    'nomenclaturalStatus_x', 
    'scientificNameID_y', 
    'scientificName_y'
]]

column_mappings = {
    'scientificNameID_x': 'scientificNameID',
    'scientificName_x': 'scientificName',
    'taxonRank_x': 'taxonRank',
    'genericName_x': 'genericName',
    'specificEpithet_x': 'specificEpithet',
    'infraspecificEpithet_x': 'infraspecificEpithet',
    'scientificNameAuthorship_x': 'scientificNameAuthorship',
    'nomenclaturalStatus_x': 'nomenclaturalStatus',
    'scientificNameID_y': 'originalNameUsageID',
    'scientificName_y': 'originalNameUsage'
}

df2 = df2.rename(columns=column_mappings)

# Filter for names without originalNameUsage
df3 = df_names[df_names['originalNameUsage'].isna()][columns]
df3.drop(columns=['nameAccordingToID'], inplace=True)

# Merge dataframes
df5 = pd.concat([df2, df3])
df5 = df5.sort_values(by='scientificName')

# Make taxonRank lowercase
df5['taxonRank'] = df5['taxonRank'].str.lower()

# Map Latin rank names to less wankerish English ones
taxon_ranks = []
uninomials = []
generic_names = []
for index, row in df5.iterrows():
    taxon_ranks.append(ranks[row['taxonRank']])

    uninomial = np.NaN
    generic_name = row['genericName']

    if not isinstance(row['genericName'], str):
        if not isinstance(row['scientificNameAuthorship'], str):
            uninomial = row['scientificName']
        else:
            uninomial = row['scientificName'][0:len(row['scientificName'])-len(row['scientificNameAuthorship'])-1]

    if row['taxonRank'] == 'genus':
        uninomial = row['genericName']
        generic_name = np.NaN

    uninomials.append(uninomial)
    generic_names.append(generic_name)

df5['taxonRank'] = taxon_ranks
df5['genericName'] = generic_names
df5['uninomial'] = uninomials

# Add nomenclaturalCode; 'ICN' in GBIF vocab. but 'botanical' in CoLDP
df5['code'] = 'botanical'

df5 = df5[~df5['nomenclaturalStatus'].isin(['isonym', 
        'nom. illeg.', 
        'nom. illeg., nom. rej.', 
        'nom. illeg., nom. superfl.', 
        'nom. inval.', 
        'nom. inval., nom. nud.', 
        'nom. inval., pro syn.', 
        'nom. superfl.', 
        'orth. var.'])]

df5 = df5[[
        'scientificNameID', 
        'taxonRank', 
        'scientificName', 
        'uninomial',
        'genericName', 
        'specificEpithet', 
        'infraspecificEpithet', 
        'scientificNameAuthorship', 
        'code', 
        'nomenclaturalStatus', 
        'originalNameUsageID', 
        'originalNameUsage']]

df_nam = df5

df5
# Out:
#                                        scientificNameID taxonRank  \
# 2796  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7582  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 2797  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 8149  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7587  https://id.biodiversity.org.au/name/ausmoss/10...   species
# ...                                                 ...       ...
# 6279  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7394  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 6280  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7831  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 6281  https://id.biodiversity.org.au/name/ausmoss/10...   species
#
#                                          scientificName uninomial  \
# 2796  Acanthocladium crinitum (Hook.f. & Wilson) Bro...       NaN
# 7582     Acanthocladium crossii Broth. & Geh. ex Broth.       NaN
# 2797            Acanthocladium extenuatum (Brid.) Mitt.       NaN
# 8149  Acanthocladium macgregorii (Broth. & Geh.) Broth.       NaN
# 7587                  Acanthocladium rigidifolium Dixon       NaN
# ...                                                 ...       ...
# 6279                         Zygodon obtusifolius Hook.       NaN
# 7394                          Zygodon preissianus Hampe       NaN
# 6280             Zygodon reinwardtii (Hornsch.) A.Braun       NaN
# 7831                       Zygodon remotidens Müll.Hal.       NaN
# 6281                             Zygodon rodwayi Broth.       NaN
#
#          genericName specificEpithet infraspecificEpithet  \
# 2796  Acanthocladium        crinitum                  NaN
# 7582  Acanthocladium         crossii                  NaN
# 2797  Acanthocladium      extenuatum                  NaN
# 8149  Acanthocladium     macgregorii                  NaN
# 7587  Acanthocladium    rigidifolium                  NaN
# ...              ...             ...                  ...
# 6279         Zygodon    obtusifolius                  NaN
# 7394         Zygodon     preissianus                  NaN
# 6280         Zygodon     reinwardtii                  NaN
# 7831         Zygodon      remotidens                  NaN
# 6281         Zygodon         rodwayi                  NaN
#
#                 scientificNameAuthorship       code nomenclaturalStatus  \
# 2796  (Hook.f. & Wilson) Broth. ex Paris  botanical                 NaN
# 7582             Broth. & Geh. ex Broth.  botanical                 NaN
# 2797                       (Brid.) Mitt.  botanical                 NaN
# 8149              (Broth. & Geh.) Broth.  botanical                 NaN
# 7587                               Dixon  botanical                 NaN
# ...                                  ...        ...                 ...
# 6279                               Hook.  botanical                 NaN
# 7394                               Hampe  botanical                 NaN
# 6280                  (Hornsch.) A.Braun  botanical                 NaN
# 7831                           Müll.Hal.  botanical                 NaN
# 6281                              Broth.  botanical                 NaN
#
#                                     originalNameUsageID  \
# 2796  https://id.biodiversity.org.au/name/ausmoss/10...
# 7582                                                NaN
# 2797  https://id.biodiversity.org.au/name/ausmoss/10...
# 8149                                                NaN
# 7587                                                NaN
# ...                                                 ...
# 6279                                                NaN
# 7394                                                NaN
# 6280                                                NaN
# 7831                                                NaN
# 6281                                                NaN
#
#                      originalNameUsage
# 2796  Hypnum crinitum Hook.f. & Wilson
# 7582                               NaN
# 2797           Hypnum extenuatum Brid.
# 8149                               NaN
# 7587                               NaN
# ...                                ...
# 6279                               NaN
# 7394                               NaN
# 6280                               NaN
# 7831                               NaN
# 6281                               NaN
#
# [7838 rows x 12 columns]

# %% [markdown]
# ### Clean up scientific names
# Remove ex-authors and remove authorship from autonyms

# %%
def remove_ex_author(auth):
    return auth[auth.index(' ex ')+4:] if ' ex ' in auth else auth

print(remove_ex_author('Hook.f. & Taylor'))
print(remove_ex_author('Taylor ex Lehm.'))
print(remove_ex_author('Broth. & Geh. ex Broth.'))
# Out:
# Hook.f. & Taylor
# Lehm.
# Broth.

# %%
def cleanup_authorship(authorship):
    authorshipParentheses = None
    if '(' in authorship:
        authorshipParentheses = remove_ex_author(authorship[1:authorship.index(')')])
        authorship = remove_ex_author(authorship[authorship.index(')')+2:])
    if authorshipParentheses:
        return '(' + authorshipParentheses + ') ' + authorship
    else:
        return remove_ex_author(authorship)

print(cleanup_authorship('(Hook.f. & Taylor) Taylor ex Lehm.'))
print(cleanup_authorship('Broth. & Geh. ex Broth.'))
# Out:
# (Hook.f. & Taylor) Lehm.
# Broth.

# %%
clean_names = []
for index, row in df_names.iterrows():
    if row['taxonRank'] in ['Regnum', 'Phylum', 'Division', 'Classis', 'Subclassis', 'Superordo', 'Ordo', 'Subordo'] \
                or (row['infraspecificEpithet'] and row['infraspecificEpithet'] == row['specificEpithet']) \
                or not isinstance(row['scientificNameAuthorship'], str):
        clean_names.append({
            'scientificNameID': row['scientificNameID'],
            'scientificName': row['canonicalName'],
            'authorship': np.NaN
        })
    else:
        clean_names.append({
            'scientificNameID': row['scientificNameID'],
            'scientificName': row['canonicalName'],
            'authorship': cleanup_authorship(row['scientificNameAuthorship'])
        })

df_clean_names = pd.DataFrame.from_dict(clean_names)

df_clean_names
# Out:
#                                        scientificNameID  \
# 0     https://id.biodiversity.org.au/name/ausmoss/20...
# 1     https://id.biodiversity.org.au/name/ausmoss/13...
# 2     https://id.biodiversity.org.au/name/ausmoss/20...
# 3     https://id.biodiversity.org.au/name/ausmoss/13...
# 4     https://id.biodiversity.org.au/name/ausmoss/21...
# ...                                                 ...
# 9073  https://id.biodiversity.org.au/name/ausmoss/12...
# 9074  https://id.biodiversity.org.au/name/ausmoss/12...
# 9075  https://id.biodiversity.org.au/name/ausmoss/12...
# 9076  https://id.biodiversity.org.au/name/ausmoss/12...
# 9077  https://id.biodiversity.org.au/name/ausmoss/12...
#
#                            scientificName                   authorship
# 0     Acrobolbus cinerascens f. attenuata                       Rodway
# 1                  Acrobolbus cinerascens  (Lehm. & Lindenb.) Schiffn.
# 2                  Acrobolbus cinerascens    (Lehm. & Lindenb.) Bastow
# 3                    Acrobolbus concinnus               (Mitt.) Grolle
# 4                      Acrobolbus cyaneus                       Herzog
# ...                                   ...                          ...
# 9073                     Jungermanniaceae                        Rchb.
# 9074                       Lophocoleaceae               Vanden Berghen
# 9075                         Scapaniaceae                         Mig.
# 9076                        Lepidoziaceae                       Limpr.
# 9077                        Adelanthaceae                       Grolle
#
# [9078 rows x 3 columns]

# %%
df_merge = df_nam.merge(df_clean_names, how='left', left_on='scientificNameID', right_on='scientificNameID')

df_merge.rename(columns={'scientificName_y': 'scientificName'}, inplace=True)
df_merge.drop(columns=['scientificName_x'], inplace=True)

df_nam = df_merge[['scientificNameID', 'taxonRank', 'scientificName', 'uninomial', 'genericName', 'specificEpithet', 
                'infraspecificEpithet', 'authorship', 'code', 'nomenclaturalStatus', 
                'originalNameUsageID', 'originalNameUsage']]

df_nam
# Out:
#                                        scientificNameID taxonRank  \
# 0     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 1     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 2     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 3     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 4     https://id.biodiversity.org.au/name/ausmoss/10...   species
# ...                                                 ...       ...
# 7833  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7834  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7835  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7836  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7837  https://id.biodiversity.org.au/name/ausmoss/10...   species
#
#                    scientificName uninomial     genericName specificEpithet  \
# 0         Acanthocladium crinitum       NaN  Acanthocladium        crinitum
# 1          Acanthocladium crossii       NaN  Acanthocladium         crossii
# 2       Acanthocladium extenuatum       NaN  Acanthocladium      extenuatum
# 3      Acanthocladium macgregorii       NaN  Acanthocladium     macgregorii
# 4     Acanthocladium rigidifolium       NaN  Acanthocladium    rigidifolium
# ...                           ...       ...             ...             ...
# 7833         Zygodon obtusifolius       NaN         Zygodon    obtusifolius
# 7834          Zygodon preissianus       NaN         Zygodon     preissianus
# 7835          Zygodon reinwardtii       NaN         Zygodon     reinwardtii
# 7836           Zygodon remotidens       NaN         Zygodon      remotidens
# 7837              Zygodon rodwayi       NaN         Zygodon         rodwayi
#
#      infraspecificEpithet                authorship       code  \
# 0                     NaN  (Hook.f. & Wilson) Paris  botanical
# 1                     NaN                    Broth.  botanical
# 2                     NaN             (Brid.) Mitt.  botanical
# 3                     NaN    (Broth. & Geh.) Broth.  botanical
# 4                     NaN                     Dixon  botanical
# ...                   ...                       ...        ...
# 7833                  NaN                     Hook.  botanical
# 7834                  NaN                     Hampe  botanical
# 7835                  NaN        (Hornsch.) A.Braun  botanical
# 7836                  NaN                 Müll.Hal.  botanical
# 7837                  NaN                    Broth.  botanical
#
#      nomenclaturalStatus                                originalNameUsageID  \
# 0                    NaN  https://id.biodiversity.org.au/name/ausmoss/10...
# 1                    NaN                                                NaN
# 2                    NaN  https://id.biodiversity.org.au/name/ausmoss/10...
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 7833                 NaN                                                NaN
# 7834                 NaN                                                NaN
# 7835                 NaN                                                NaN
# 7836                 NaN                                                NaN
# 7837                 NaN                                                NaN
#
#                      originalNameUsage
# 0     Hypnum crinitum Hook.f. & Wilson
# 1                                  NaN
# 2              Hypnum extenuatum Brid.
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 7833                               NaN
# 7834                               NaN
# 7835                               NaN
# 7836                               NaN
# 7837                               NaN
#
# [7838 rows x 12 columns]

# %% [markdown]
# ### Set nomenclatural status

# %%
df_nam.rename(columns={'nomenclaturalStatus': 'status'}, inplace=True)

stat = []
for index, row in df_nam.iterrows():
    if isinstance(row['status'], str):
        if 'cons.' in row['status']:
            stat.append('conserved')
        else:
            if 'rej.' in row['status']:
                stat.append('rejected')
            else:
                stat.append(np.NaN)
    else:
        stat.append('acceptable')

df_nam['status'] = stat

df_nam
# Out:
# /tmp/ipykernel_2356/1894582402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nam.rename(columns={'nomenclaturalStatus': 'status'}, inplace=True)
# /tmp/ipykernel_2356/1894582402.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nam['status'] = stat
#                                        scientificNameID taxonRank  \
# 0     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 1     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 2     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 3     https://id.biodiversity.org.au/name/ausmoss/10...   species
# 4     https://id.biodiversity.org.au/name/ausmoss/10...   species
# ...                                                 ...       ...
# 7833  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7834  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7835  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7836  https://id.biodiversity.org.au/name/ausmoss/10...   species
# 7837  https://id.biodiversity.org.au/name/ausmoss/10...   species
#
#                    scientificName uninomial     genericName specificEpithet  \
# 0         Acanthocladium crinitum       NaN  Acanthocladium        crinitum
# 1          Acanthocladium crossii       NaN  Acanthocladium         crossii
# 2       Acanthocladium extenuatum       NaN  Acanthocladium      extenuatum
# 3      Acanthocladium macgregorii       NaN  Acanthocladium     macgregorii
# 4     Acanthocladium rigidifolium       NaN  Acanthocladium    rigidifolium
# ...                           ...       ...             ...             ...
# 7833         Zygodon obtusifolius       NaN         Zygodon    obtusifolius
# 7834          Zygodon preissianus       NaN         Zygodon     preissianus
# 7835          Zygodon reinwardtii       NaN         Zygodon     reinwardtii
# 7836           Zygodon remotidens       NaN         Zygodon      remotidens
# 7837              Zygodon rodwayi       NaN         Zygodon         rodwayi
#
#      infraspecificEpithet                authorship       code      status  \
# 0                     NaN  (Hook.f. & Wilson) Paris  botanical  acceptable
# 1                     NaN                    Broth.  botanical  acceptable
# 2                     NaN             (Brid.) Mitt.  botanical  acceptable
# 3                     NaN    (Broth. & Geh.) Broth.  botanical  acceptable
# 4                     NaN                     Dixon  botanical  acceptable
# ...                   ...                       ...        ...         ...
# 7833                  NaN                     Hook.  botanical  acceptable
# 7834                  NaN                     Hampe  botanical  acceptable
# 7835                  NaN        (Hornsch.) A.Braun  botanical  acceptable
# 7836                  NaN                 Müll.Hal.  botanical  acceptable
# 7837                  NaN                    Broth.  botanical  acceptable
#
#                                     originalNameUsageID  \
# 0     https://id.biodiversity.org.au/name/ausmoss/10...
# 1                                                   NaN
# 2     https://id.biodiversity.org.au/name/ausmoss/10...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7833                                                NaN
# 7834                                                NaN
# 7835                                                NaN
# 7836                                                NaN
# 7837                                                NaN
#
#                      originalNameUsage
# 0     Hypnum crinitum Hook.f. & Wilson
# 1                                  NaN
# 2              Hypnum extenuatum Brid.
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 7833                               NaN
# 7834                               NaN
# 7835                               NaN
# 7836                               NaN
# 7837                               NaN
#
# [7838 rows x 12 columns]

# %% [markdown]
# ### Name relations
#
# basionyms and replaced names

# %%
df_name_relationships = df5[~df5['originalNameUsageID'].isna()][['scientificNameID', 'scientificName', 'originalNameUsageID', 'originalNameUsage']]

namerels = []
for index, row in df_name_relationships.iterrows():
    rel = {}
    if '(' in row['scientificName']:
        rel['nameID'] = row['scientificNameID']
        # rel['name'] = row['scientificName']
        rel['type'] = 'basionym'
        rel['relatedNameID'] = row['originalNameUsageID']
        # rel['relatedName'] = row['originalNameUsage']
    else:
        rel['nameID'] = row['originalNameUsageID']
        # rel['name'] = row['originalNameUsage']
        rel['type'] = 'replacement name'
        rel['relatedNameID'] = row['scientificNameID']
        # rel['relatedName'] = row['scientificName']
    namerels.append(rel)

df_namerel = pd.DataFrame.from_dict(namerels)

# Remove originalNameUsage columns from Names
drop_columns = [
    'originalNameUsageID',
    'originalNameUsage',
    'nomenclaturalStatus'
]

rename_columns = {
    'scientificNameID': 'ID',
    'taxonRank': 'rank',
    'scientificName': 'scientificName',
    'genericName': 'genus',
    'scientificNameAuthorship': 'authorship'
}

df5.drop(columns=drop_columns, inplace=True)
df5.rename(columns=rename_columns, inplace=True)

# %% [markdown]
# ### Taxa

# %%
# Read Taxon export into dataframe
df_taxa = pd.read_csv('data/' + group + '/taxa.csv')

# Create dataframe with IDs
# This is used later to replace tree element IDs (in taxonID) with instance IDs (in taxonConceptID)
df_id = df_taxa[['taxonID', 'taxonConceptID']]
# df_id.to_csv('coldp/' + group + '/id.tsv', sep='\t', index=False)

df_taxa = df_taxa[df_taxa['nameType'].isin(['scientific', 'autonym'])]

# %%
# Filter on accepted names; these are the taxa
df_tax = df_taxa[df_taxa['taxonomicStatus'] == 'accepted']

# Replace tree element IDs in taxonID with instance IDs (see above)
df_tax['taxonID'] = df_tax['taxonConceptID']

# Replace tree element IDs in parentNameUsageID with instance IDs
df_tax = df_tax.merge(df_id, how='left', left_on='parentNameUsageID', right_on='taxonID')
df_tax['parentNameUsageID'] = df_tax['taxonConceptID_y']
df_tax.drop(columns=['taxonID_y', 'taxonConceptID_y'], inplace=True)
df_tax.rename(columns={'taxonID_x': 'taxonID', 'taxonConceptID_x': 'taxonConceptID'}, inplace=True)

df_tax = df_tax[['taxonID',
 'scientificNameID',
 'scientificName',
 'scientificNameAuthorship',
 'nameAccordingTo',
 'nameAccordingToID',
 'parentNameUsageID',
 'taxonRank',
 'taxonRankSortOrder',
 'kingdom',
 'class',
 'subclass',
 'family',
 'taxonConceptID',
 'taxonRemarks',
 'higherClassification'
]]

# Translate ranks into English
df_tax['taxonRank'] = df_tax['taxonRank'].str.lower()

taxon_ranks = []
for index, row in df_tax.iterrows():
    taxon_ranks.append(ranks[row['taxonRank']])

df_tax['taxonRank'] = taxon_ranks
# Out:
# /tmp/ipykernel_2356/2296980726.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tax['taxonID'] = df_tax['taxonConceptID']

# %% [markdown]
# #### Higher classification
#
# (will not be added to CoLDP)

# %%
# Create dictionary with higher taxa from instance ID
def get_higher_taxa(id, higher={}):
    row = df_tax.loc[df_tax['taxonID'] == id]

    if len(row) > 0:
        parent = row[[
            'taxonRank', 
            'scientificName', 
            'scientificNameAuthorship', 
            'parentNameUsageID']].to_dict(orient='records')[0]
        
        if isinstance(parent['scientificNameAuthorship'], str):
            higher[parent['taxonRank']] = parent['scientificName'][0:len(parent['scientificName'])-len(parent['scientificNameAuthorship'])-1]
        else:
            higher[parent['taxonRank']] = parent['scientificName']

        if isinstance(parent['parentNameUsageID'], str):
            return get_higher_taxa(parent['parentNameUsageID'], higher)
        else:
            return higher
    else:
        return higher

# %%
# Create higher classification
def create_higher_classification(id):
    higher = get_higher_taxa(id, {})
    keys = list(higher.keys())

    hcl = {}

    hcl['taxonID'] = id
    hcl['species'] = higher['species'] if 'species' in keys else np.NaN
    hcl['section'] = higher['section'] if 'section' in keys else np.NaN
    hcl['subgenus'] = higher['subgenus'] if 'subgenus' in keys else np.NaN
    hcl['genus'] = higher['genus'] if 'genus' in keys else np.NaN
    hcl['subtribe'] = higher['subtribe'] if 'subtribe' in keys else np.NaN
    hcl['tribe'] = higher['tribe'] if 'tribe' in keys else np.NaN
    hcl['subfamily'] = higher['subfamily'] if 'subfamily' in keys else np.NaN
    hcl['family'] = higher['family'] if 'family' in keys else np.NaN
    hcl['superfamily'] = higher['superfamily'] if 'superfamily' in keys else np.NaN
    hcl['suborder'] = higher['suborder'] if 'suborder' in keys else np.NaN
    hcl['order'] = higher['order'] if 'order' in keys else np.NaN
    hcl['subclass'] = higher['subclass'] if 'subclass' in keys else np.NaN
    hcl['class'] = higher['class'] if 'class' in keys else np.NaN
    hcl['subphylum'] = higher['subphylum'] if 'subphylum' in keys else np.NaN
    hcl['phylum'] = higher['phylum'] if 'phylum' in keys else np.NaN
    hcl['kingdom'] = higher['kingdom'] if 'kingdom' in keys else np.NaN

    cl = list(higher.values())
    for i in range(len(cl) // 2):
        cl[i], cl[-1 - i] = cl[-1 - i], cl[i]

    hcl['classification'] = ' | '.join(cl)

    return hcl

# %%
cl = []
for index, row in df_tax.iterrows():
    cl.append(create_higher_classification(row['taxonID']))

df_higher = pd.DataFrame.from_dict(cl)

df_higher = df_higher.merge(df_tax[['taxonID', 'scientificName', 'taxonRank']], how='left', left_on='taxonID', right_on='taxonID')

df_higher = df_higher[['taxonID',
 'scientificName',
 'taxonRank',
 'kingdom',
 'phylum',
 'subphylum',
 'class',
 'subclass',
 'order',
 'suborder',
 'superfamily',
 'family',
 'tribe',
 'subfamily',
 'subtribe',
 'genus',
 'subgenus',
 'section',
 'species',
 'classification']]

df_higher.rename(columns={'classification': 'higherClassification'}, inplace=True)

df_higher
# Out:
#                                                 taxonID  \
# 0     https://id.biodiversity.org.au/instance/ausmos...
# 1     https://id.biodiversity.org.au/instance/ausmos...
# 2     https://id.biodiversity.org.au/instance/ausmos...
# 3     https://id.biodiversity.org.au/instance/ausmos...
# 4     https://id.biodiversity.org.au/instance/ausmos...
# ...                                                 ...
# 2607  https://id.biodiversity.org.au/instance/ausmos...
# 2608  https://id.biodiversity.org.au/instance/ausmos...
# 2609  https://id.biodiversity.org.au/instance/ausmos...
# 2610  https://id.biodiversity.org.au/instance/ausmos...
# 2611  https://id.biodiversity.org.au/instance/ausmos...
#
#                                          scientificName taxonRank  kingdom  \
# 0                                       Plantae Haeckel   kingdom  Plantae
# 1     Anthocerotophyta Rothm. ex Stotler & Crand.-St...    phylum  Plantae
# 2                    Anthocerotopsida de Bary ex Jancz.     class  Plantae
# 3                                Anthocerotidae Rosenv.  subclass  Plantae
# 4                                 Anthocerotales Limpr.     order  Plantae
# ...                                                 ...       ...      ...
# 2607                           Riella halophila Banwell   species  Plantae
# 2608                          Riella spiculata J.Taylor   species  Plantae
# 2609                              Sphaerocarpaceae Heeg    family  Plantae
# 2610                               Sphaerocarpos Boehm.     genus  Plantae
# 2611                       Sphaerocarpos texanus Austin   species  Plantae
#
#                 phylum  subphylum             class        subclass  \
# 0                  NaN        NaN               NaN             NaN
# 1     Anthocerotophyta        NaN               NaN             NaN
# 2     Anthocerotophyta        NaN  Anthocerotopsida             NaN
# 3     Anthocerotophyta        NaN  Anthocerotopsida  Anthocerotidae
# 4     Anthocerotophyta        NaN  Anthocerotopsida  Anthocerotidae
# ...                ...        ...               ...             ...
# 2607   Marchantiophyta        NaN   Marchantiopsida   Marchantiidae
# 2608   Marchantiophyta        NaN   Marchantiopsida   Marchantiidae
# 2609   Marchantiophyta        NaN   Marchantiopsida   Marchantiidae
# 2610   Marchantiophyta        NaN   Marchantiopsida   Marchantiidae
# 2611   Marchantiophyta        NaN   Marchantiopsida   Marchantiidae
#
#                 order suborder  superfamily            family  tribe  \
# 0                 NaN      NaN          NaN               NaN    NaN
# 1                 NaN      NaN          NaN               NaN    NaN
# 2                 NaN      NaN          NaN               NaN    NaN
# 3                 NaN      NaN          NaN               NaN    NaN
# 4      Anthocerotales      NaN          NaN               NaN    NaN
# ...               ...      ...          ...               ...    ...
# 2607  Sphaerocarpales      NaN          NaN        Riellaceae    NaN
# 2608  Sphaerocarpales      NaN          NaN        Riellaceae    NaN
# 2609  Sphaerocarpales      NaN          NaN  Sphaerocarpaceae    NaN
# 2610  Sphaerocarpales      NaN          NaN  Sphaerocarpaceae    NaN
# 2611  Sphaerocarpales      NaN          NaN  Sphaerocarpaceae    NaN
#
#      subfamily  subtribe          genus subgenus section  \
# 0          NaN       NaN            NaN      NaN     NaN
# 1          NaN       NaN            NaN      NaN     NaN
# 2          NaN       NaN            NaN      NaN     NaN
# 3          NaN       NaN            NaN      NaN     NaN
# 4          NaN       NaN            NaN      NaN     NaN
# ...        ...       ...            ...      ...     ...
# 2607       NaN       NaN         Riella      NaN     NaN
# 2608       NaN       NaN         Riella      NaN     NaN
# 2609       NaN       NaN            NaN      NaN     NaN
# 2610       NaN       NaN  Sphaerocarpos      NaN     NaN
# 2611       NaN       NaN  Sphaerocarpos      NaN     NaN
#
#                     species                               higherClassification
# 0                       NaN                                            Plantae
# 1                       NaN                         Plantae | Anthocerotophyta
# 2                       NaN      Plantae | Anthocerotophyta | Anthocerotopsida
# 3                       NaN  Plantae | Anthocerotophyta | Anthocerotopsida ...
# 4                       NaN  Plantae | Anthocerotophyta | Anthocerotopsida ...
# ...                     ...                                                ...
# 2607       Riella halophila  Plantae | Marchantiophyta | Marchantiopsida | ...
# 2608       Riella spiculata  Plantae | Marchantiophyta | Marchantiopsida | ...
# 2609                    NaN  Plantae | Marchantiophyta | Marchantiopsida | ...
# 2610                    NaN  Plantae | Marchantiophyta | Marchantiopsida | ...
# 2611  Sphaerocarpos texanus  Plantae | Marchantiophyta | Marchantiopsida | ...
#
# [2612 rows x 20 columns]

# %% [markdown]
# #### Synonyms

# %%
# Filter on synonyms

if group == 'bryophytes':
    df_syn = df_taxa[df_taxa['taxonomicStatus'].isin(['taxonomic synonym']) & ~df_taxa['acceptedNameUsageID'].isna()][[
        'taxonID',
        'scientificNameID',
        'scientificName',
        'acceptedNameUsageID',
        'acceptedNameUsage',
        'taxonomicStatus'
    ]]
    df_syn = df_syn[~df_syn['scientificName'].str.contains('\(')]
else:
    df_syn = df_taxa[df_taxa['taxonomicStatus'].isin(['synonym', 'nomenclatural synonym', 'taxonomic synonym']) & ~df_taxa['acceptedNameUsageID'].isna()][[
        'taxonID',
        'scientificNameID',
        'scientificName',
        'acceptedNameUsageID',
        'acceptedNameUsage',
        'taxonomicStatus'
    ]]

# Replace tree element IDs in acceptedNameUsageID with instance IDs
df_syn = df_syn.merge(df_id, how='left', left_on='acceptedNameUsageID', right_on='taxonID')

df_syn.drop(columns=['acceptedNameUsageID', 'taxonID_y'], inplace=True)
df_syn.rename(columns={
    'taxonID_x': 'ID',
    'taxonConceptID': 'taxonID',
    'scientificNameID': 'nameID'    
}, inplace=True)
df_syn = df_syn[['ID', 'taxonID', 'nameID', 'scientificName', 'acceptedNameUsage', 'taxonomicStatus']]

# Get accepted names
df_dwc_syn = df_syn.merge(df_tax[['taxonID', 'scientificName']], left_on='taxonID', right_on='taxonID')

df_dwc_syn.drop(columns=['taxonID', 'nameID', 'acceptedNameUsage'], inplace=True)

df_dwc_syn.rename(columns={
    'ID': 'taxonID',
    'scientificName_x': 'scientificName',
    'scientificName_y': 'acceptedNameUsage'
}, inplace=True)

# df_syn.drop(columns=['scientificName', 'acceptedNameUsage', 'taxonomicStatus'], inplace=True)

df_syn = df_syn[['ID', 'taxonID', 'acceptedNameUsage', 'nameID', 'scientificName']].rename(columns={'acceptedNameUsage': 'acceptedName', 'scientificName': 'synonym'})
df_syn['remarks'] = 'heterotypic synonym'
df_syn
# Out:
#                                                      ID  \
# 0     https://id.biodiversity.org.au/instance/ausmos...
# 1     https://id.biodiversity.org.au/instance/apni/8...
# 2     https://id.biodiversity.org.au/instance/apni/8...
# 3     https://id.biodiversity.org.au/instance/apni/8...
# 4     https://id.biodiversity.org.au/instance/apni/8...
# ...                                                 ...
# 1746  https://id.biodiversity.org.au/instance/apni/8...
# 1747  https://id.biodiversity.org.au/instance/apni/8...
# 1748  https://id.biodiversity.org.au/instance/apni/8...
# 1749  https://id.biodiversity.org.au/instance/apni/9...
# 1750  https://id.biodiversity.org.au/instance/apni/8...
#
#                                                 taxonID  \
# 0     https://id.biodiversity.org.au/instance/ausmos...
# 1     https://id.biodiversity.org.au/instance/ausmos...
# 2     https://id.biodiversity.org.au/instance/ausmos...
# 3     https://id.biodiversity.org.au/instance/ausmos...
# 4     https://id.biodiversity.org.au/instance/ausmos...
# ...                                                 ...
# 1746  https://id.biodiversity.org.au/instance/ausmos...
# 1747  https://id.biodiversity.org.au/instance/ausmos...
# 1748  https://id.biodiversity.org.au/instance/ausmos...
# 1749  https://id.biodiversity.org.au/instance/ausmos...
# 1750  https://id.biodiversity.org.au/instance/ausmos...
#
#                                          acceptedName  \
# 0                          Anthoceros fragilis Steph.
# 1           Megaceros pellucidus (Colenso) E.A.Hodgs.
# 2             Phaeoceros carolinianus (Michx.) Prosk.
# 3             Phaeoceros carolinianus (Michx.) Prosk.
# 4             Phaeoceros carolinianus (Michx.) Prosk.
# ...                                               ...
# 1746                            Riccia limbata Bisch.
# 1747                         Riccia macrospora Steph.
# 1748                         Riccia macrospora Steph.
# 1749  Riccia multifida (Steph.) Steph. var. multifida
# 1750                          Targionia hypophylla L.
#
#                                                  nameID  \
# 0     https://id.biodiversity.org.au/name/ausmoss/20...
# 1     https://id.biodiversity.org.au/name/ausmoss/12...
# 2     https://id.biodiversity.org.au/name/ausmoss/20...
# 3     https://id.biodiversity.org.au/name/ausmoss/20...
# 4     https://id.biodiversity.org.au/name/ausmoss/20...
# ...                                                 ...
# 1746  https://id.biodiversity.org.au/name/ausmoss/21...
# 1747  https://id.biodiversity.org.au/name/ausmoss/21...
# 1748  https://id.biodiversity.org.au/name/ausmoss/21...
# 1749  https://id.biodiversity.org.au/name/ausmoss/21...
# 1750  https://id.biodiversity.org.au/name/ausmoss/21...
#
#                                           synonym              remarks
# 0                      Anthoceros fertilis Steph.  heterotypic synonym
# 1     Anthoceros longispirus Carrington & Pearson  heterotypic synonym
# 2                 Anthoceros multicapsulus Steph.  heterotypic synonym
# 3                      Anthoceros brotheri Steph.  heterotypic synonym
# 4                      Anthoceros communis Steph.  heterotypic synonym
# ...                                           ...                  ...
# 1746                           Riccia lata Taylor  heterotypic synonym
# 1747                     Riccia rubrispora Steph.  heterotypic synonym
# 1748                  Riccia sellingii S.W.Arnell  heterotypic synonym
# 1749                   Riccia burnettensis Steph.  heterotypic synonym
# 1750                     Targionia michelii Corda  heterotypic synonym
#
# [1751 rows x 6 columns]

# %%
# basionym of accepted name
df_acc_comb = df_tax[~df_tax['scientificNameAuthorship'].isna() & df_tax['scientificNameAuthorship'].str.contains('\(')][['taxonID', 'scientificNameID', 'scientificName', 'scientificNameAuthorship']]
df_m1 = df_acc_comb.merge(df_namerel[df_namerel['type'] == 'basionym'], how='inner', left_on='scientificNameID', right_on='nameID')
df_m2 = df_m1.merge(df_nam[['scientificNameID', 'scientificName']], how='left', left_on='relatedNameID', right_on='scientificNameID')

df_acc_bas = df_m2[['taxonID', 'scientificName_x', 'relatedNameID', 'scientificName_y']].rename(columns={'relatedNameID': 'nameID', 'scientificName_x': 'acceptedName', 'scientificName_y': 'synonym'})
df_acc_bas['remarks'] = 'basionym of accepted name'
df_acc_bas
# Out:
#                                                 taxonID  \
# 0     https://id.biodiversity.org.au/instance/ausmos...
# 1     https://id.biodiversity.org.au/instance/ausmos...
# 2     https://id.biodiversity.org.au/instance/ausmos...
# 3     https://id.biodiversity.org.au/instance/ausmos...
# 4     https://id.biodiversity.org.au/instance/ausmos...
# ...                                                 ...
# 1039  https://id.biodiversity.org.au/instance/ausmos...
# 1040  https://id.biodiversity.org.au/instance/ausmos...
# 1041  https://id.biodiversity.org.au/instance/ausmos...
# 1042  https://id.biodiversity.org.au/instance/ausmos...
# 1043  https://id.biodiversity.org.au/instance/ausmos...
#
#                                            acceptedName  \
# 0            Folioceros fuciformis (Mont.) D.C.Bhardwaj
# 1     Folioceros glandulosus (Lehm. & Lindenb.) D.C....
# 2                    Dendroceros crispatus (Hook.) Nees
# 3                    Megaceros carnosus (Steph.) Steph.
# 4                 Megaceros denticulatus (Lehm.) Steph.
# ...                                                 ...
# 1039                 Preissia commutata (Lindenb.) Nees
# 1040                   Riccia multifida (Steph.) Steph.
# 1041                    Riccia papulosa (Steph.) Steph.
# 1042    Riccia vesiculosa (Carrington & Pearson) Steph.
# 1043                     Ricciocarpos natans (L.) Corda
#
#                                                  nameID  \
# 0     https://id.biodiversity.org.au/name/ausmoss/14...
# 1     https://id.biodiversity.org.au/name/ausmoss/12...
# 2     https://id.biodiversity.org.au/name/ausmoss/21...
# 3     https://id.biodiversity.org.au/name/ausmoss/17...
# 4     https://id.biodiversity.org.au/name/ausmoss/21...
# ...                                                 ...
# 1039  https://id.biodiversity.org.au/name/ausmoss/21...
# 1040  https://id.biodiversity.org.au/name/ausmoss/21...
# 1041  https://id.biodiversity.org.au/name/ausmoss/21...
# 1042  https://id.biodiversity.org.au/name/ausmoss/21...
# 1043  https://id.biodiversity.org.au/name/ausmoss/15...
#
#                              synonym                    remarks
# 0              Anthoceros fuciformis  basionym of accepted name
# 1             Anthoceros glandulosus  basionym of accepted name
# 2                  Monoclea crispata  basionym of accepted name
# 3                Anthoceros carnosus  basionym of accepted name
# 4            Anthoceros denticulatus  basionym of accepted name
# ...                              ...                        ...
# 1039            Marchantia commutata  basionym of accepted name
# 1040             Ricciella multifida  basionym of accepted name
# 1041              Ricciella papulosa  basionym of accepted name
# 1042  Riccia bullosa var. vesiculosa  basionym of accepted name
# 1043                   Riccia natans  basionym of accepted name
#
# [1044 rows x 5 columns]

# %%
# other combinations of basionyms of accepted names
df_m3 = df_acc_bas.merge(df_namerel[df_namerel['type'] == 'basionym'], how='left', left_on='nameID', right_on='relatedNameID')
df_m4 = df_m3.merge(df_nam[['scientificNameID', 'scientificName']], how='left', left_on='nameID_y', right_on='scientificNameID')

df_acc_other_comb = df_m4[df_m4['acceptedName'] != df_m4['scientificName']][['taxonID', 'acceptedName', 'scientificNameID', 'scientificName']].rename(columns={'scientificName': 'synonym', 'scientificNameID': 'nameID'})
df_acc_other_comb['remarks'] = 'other combination of basionym of accepted name'
df_acc_other_comb
# Out:
#                                                 taxonID  \
# 0     https://id.biodiversity.org.au/instance/ausmos...
# 1     https://id.biodiversity.org.au/instance/ausmos...
# 2     https://id.biodiversity.org.au/instance/ausmos...
# 3     https://id.biodiversity.org.au/instance/ausmos...
# 4     https://id.biodiversity.org.au/instance/ausmos...
# ...                                                 ...
# 1638  https://id.biodiversity.org.au/instance/ausmos...
# 1639  https://id.biodiversity.org.au/instance/ausmos...
# 1640  https://id.biodiversity.org.au/instance/ausmos...
# 1641  https://id.biodiversity.org.au/instance/ausmos...
# 1642  https://id.biodiversity.org.au/instance/ausmos...
#
#                                            acceptedName  \
# 0            Folioceros fuciformis (Mont.) D.C.Bhardwaj
# 1     Folioceros glandulosus (Lehm. & Lindenb.) D.C....
# 2     Folioceros glandulosus (Lehm. & Lindenb.) D.C....
# 3                    Dendroceros crispatus (Hook.) Nees
# 4                    Megaceros carnosus (Steph.) Steph.
# ...                                                 ...
# 1638                   Riccia multifida (Steph.) Steph.
# 1639                    Riccia papulosa (Steph.) Steph.
# 1640                    Riccia papulosa (Steph.) Steph.
# 1641    Riccia vesiculosa (Carrington & Pearson) Steph.
# 1642                     Ricciocarpos natans (L.) Corda
#
#                                                  nameID  \
# 0     https://id.biodiversity.org.au/name/ausmoss/14...
# 1     https://id.biodiversity.org.au/name/ausmoss/20...
# 2     https://id.biodiversity.org.au/name/ausmoss/13...
# 3     https://id.biodiversity.org.au/name/ausmoss/17...
# 4     https://id.biodiversity.org.au/name/ausmoss/17...
# ...                                                 ...
# 1638  https://id.biodiversity.org.au/name/ausmoss/13...
# 1639  https://id.biodiversity.org.au/name/ausmoss/15...
# 1640  https://id.biodiversity.org.au/name/ausmoss/19...
# 1641  https://id.biodiversity.org.au/name/ausmoss/15...
# 1642  https://id.biodiversity.org.au/name/ausmoss/15...
#
#                             synonym  \
# 0             Folioceros fuciformis
# 1           Aspiromitus glandulosus
# 2            Folioceros glandulosus
# 3             Dendroceros crispatus
# 4                Megaceros carnosus
# ...                             ...
# 1638               Riccia multifida
# 1639                Riccia papulosa
# 1640  Riccia papulosa var. papulosa
# 1641              Riccia vesiculosa
# 1642            Ricciocarpos natans
#
#                                              remarks
# 0     other combination of basionym of accepted name
# 1     other combination of basionym of accepted name
# 2     other combination of basionym of accepted name
# 3     other combination of basionym of accepted name
# 4     other combination of basionym of accepted name
# ...                                              ...
# 1638  other combination of basionym of accepted name
# 1639  other combination of basionym of accepted name
# 1640  other combination of basionym of accepted name
# 1641  other combination of basionym of accepted name
# 1642  other combination of basionym of accepted name
#
# [1643 rows x 5 columns]

# %%
# replaced names
df_acc_orig = df_tax[~(df_tax['scientificNameAuthorship'].isna() | df_tax['scientificNameAuthorship'].str.contains('\('))][['taxonID', 'scientificNameID', 'scientificName', 'scientificNameAuthorship']]
df_m5 = df_acc_orig.merge(df_namerel[df_namerel['type'] == 'replacement name'], how='inner', left_on='scientificNameID', right_on='relatedNameID')
df_m6 = df_m5.merge(df_nam[['scientificNameID', 'scientificName']], how='inner', left_on='nameID', right_on='scientificNameID')

df_replaced = df_m6[['taxonID', 'scientificName_x', 'nameID', 'scientificName_y']].rename(columns={'scientificName_x': 'acceptedName', 'scientificName_y': 'synonym'})
df_replaced['remarks'] = 'replaced name'
df_replaced
# Out:
# Empty DataFrame
# Columns: [taxonID, acceptedName, nameID, synonym, remarks]
# Index: []

# %%
# combinations of replaced names
df_m7 = df_replaced.merge(df_namerel[df_namerel['type'] == 'basionym'], how='inner', left_on='nameID', right_on='relatedNameID')
df_m8 = df_m7.merge(df_nam[['scientificNameID', 'scientificName']], how='inner', left_on='relatedNameID', right_on='scientificNameID')
df_m8

df_replaced_comb = df_m8[['taxonID', 'acceptedName', 'nameID_y', 'scientificName']].rename(columns={'nameID_y': 'nameID', 'scientificName': 'synonym'})
df_replaced_comb['remarks'] = 'combination of replaced name'
df_replaced_comb
# Out:
# Empty DataFrame
# Columns: [taxonID, acceptedName, nameID, synonym, remarks]
# Index: []

# %%
df_het_comb = df_syn.merge(df_namerel[df_namerel['type'] == 'basionym'], how='inner', left_on='nameID', right_on='relatedNameID')\
        .merge(df_nam[['scientificNameID', 'scientificName']], how='inner', left_on='nameID_y', right_on='scientificNameID')\
        [['taxonID', 'acceptedName', 'scientificNameID', 'scientificName']]\
        .rename(columns={'scientificNameID': 'nameID', 'scientificName': 'synonym'})
df_het_comb['remarks'] = 'combination of heterotypic synonym'
df_het_comb
# Out:
#                                                taxonID  \
# 0    https://id.biodiversity.org.au/instance/ausmos...
# 1    https://id.biodiversity.org.au/instance/ausmos...
# 2    https://id.biodiversity.org.au/instance/ausmos...
# 3    https://id.biodiversity.org.au/instance/ausmos...
# 4    https://id.biodiversity.org.au/instance/ausmos...
# ..                                                 ...
# 678  https://id.biodiversity.org.au/instance/ausmos...
# 679  https://id.biodiversity.org.au/instance/ausmos...
# 680  https://id.biodiversity.org.au/instance/ausmos...
# 681  https://id.biodiversity.org.au/instance/ausmos...
# 682  https://id.biodiversity.org.au/instance/ausmos...
#
#                                           acceptedName  \
# 0            Megaceros pellucidus (Colenso) E.A.Hodgs.
# 1                 Andreaea acutifolia Hook.f. & Wilson
# 2    Pyrrhobryum mnioides subsp. contortum (Müll.Ha...
# 3    Pyrrhobryum mnioides subsp. contortum (Müll.Ha...
# 4    Pyrrhobryum mnioides subsp. contortum (Müll.Ha...
# ..                                                 ...
# 678       Symphyogyna podophylla (Thunb.) Mont. & Nees
# 679  Plagiochasma rupestre (J.R.Forst. & G.Forst.) ...
# 680                  Reboulia hemisphaerica (L.) Raddi
# 681             Marchantia berteroana Lehm. & Lindenb.
# 682                            Riccia cavernosa Hoffm.
#
#                                                 nameID  \
# 0    https://id.biodiversity.org.au/name/ausmoss/12...
# 1    https://id.biodiversity.org.au/name/ausmoss/10...
# 2    https://id.biodiversity.org.au/name/ausmoss/10...
# 3    https://id.biodiversity.org.au/name/ausmoss/10...
# 4    https://id.biodiversity.org.au/name/ausmoss/10...
# ..                                                 ...
# 678  https://id.biodiversity.org.au/name/ausmoss/21...
# 679  https://id.biodiversity.org.au/name/ausmoss/21...
# 680  https://id.biodiversity.org.au/name/ausmoss/13...
# 681  https://id.biodiversity.org.au/name/ausmoss/21...
# 682  https://id.biodiversity.org.au/name/ausmoss/21...
#
#                                   synonym                             remarks
# 0                   Megaceros longispirus  combination of heterotypic synonym
# 1    Andreaea amblyophylla var. attenuata  combination of heterotypic synonym
# 2                     Rhizogonium hookeri  combination of heterotypic synonym
# 3                Rhizogonium mossmanianum  combination of heterotypic synonym
# 4                      Pogonatum gullweri  combination of heterotypic synonym
# ..                                    ...                                 ...
# 678                   Symphyogyna obovata  combination of heterotypic synonym
# 679                     Aitonia australis  combination of heterotypic synonym
# 680                Reboulia queenslandica  combination of heterotypic synonym
# 681  Marchantia polymorpha var. tabularis  combination of heterotypic synonym
# 682                 Riccia multilamellata  combination of heterotypic synonym
#
# [683 rows x 5 columns]

# %%
df_inferred = pd.concat([df_acc_bas, df_acc_other_comb, df_replaced, df_replaced_comb, df_het_comb])
df_inferred.insert(0, 'ID', range(1, 1 + len(df_inferred)))
df_inferred = df_inferred.astype({'ID': 'str'})
df_inferred['ID'] = 'ausmoss-synonym-inferred-' + df_inferred['ID']

df_hom = df_inferred[df_inferred['remarks'] != 'combination of heterotypic synonym']

df_het = df_inferred[df_inferred['remarks'] == 'combination of heterotypic synonym']

df_syn2 = pd.concat([df_hom, df_syn, df_het])
df_syn = df_syn2.merge(df_nam[['scientificNameID']], how='inner', left_on='nameID', right_on='scientificNameID').drop(columns=['scientificNameID', 'acceptedName', 'synonym'])

# %% [markdown]
# ### Remove names that are not used in taxonomy

# %%
df1 = df_tax[['taxonID', 'scientificNameID']].rename(columns={'taxonID': 'ID', 'scientificNameID': 'nameID'})
df2 = df_syn[['ID', 'nameID']]
df_used = pd.concat([df1, df2])
# df_used = df_used.drop_duplicates()
df_used

df_nam = df_nam.merge(df_used, how='inner', left_on='scientificNameID', right_on='nameID').drop(columns=['ID', 'nameID'])

# %%
df_namerel = df_namerel.merge(df_nam[['scientificNameID']], how='inner', left_on='nameID', right_on='scientificNameID').drop(columns=['scientificNameID'])\
        .merge(df_nam[['scientificNameID']], how='inner', left_on='relatedNameID', right_on='scientificNameID').drop(columns=['scientificNameID'])\
        .drop_duplicates()

# %% [markdown]
# #### Remove excess columns

# %%
df_tax = df_tax[['taxonID',
 'scientificNameID',
 'nameAccordingToID',
 'parentNameUsageID',
 'taxonRemarks']]

df_tax.rename(columns={
    'taxonID': 'ID',
    'scientificNameID': 'nameID',
    'nameAccordingToID': 'accordingToID',
    'parentNameUsageID': 'parentID',
    'taxonRemarks': 'remarks'
}, inplace=True)

df_tax
# Out:
#                                                      ID  \
# 0     https://id.biodiversity.org.au/instance/ausmos...
# 1     https://id.biodiversity.org.au/instance/ausmos...
# 2     https://id.biodiversity.org.au/instance/ausmos...
# 3     https://id.biodiversity.org.au/instance/ausmos...
# 4     https://id.biodiversity.org.au/instance/ausmos...
# ...                                                 ...
# 2607  https://id.biodiversity.org.au/instance/ausmos...
# 2608  https://id.biodiversity.org.au/instance/ausmos...
# 2609  https://id.biodiversity.org.au/instance/ausmos...
# 2610  https://id.biodiversity.org.au/instance/ausmos...
# 2611  https://id.biodiversity.org.au/instance/ausmos...
#
#                                                  nameID  \
# 0     https://id.biodiversity.org.au/name/ausmoss/10...
# 1     https://id.biodiversity.org.au/name/ausmoss/23...
# 2     https://id.biodiversity.org.au/name/ausmoss/23...
# 3     https://id.biodiversity.org.au/name/ausmoss/24...
# 4     https://id.biodiversity.org.au/name/ausmoss/14...
# ...                                                 ...
# 2607  https://id.biodiversity.org.au/name/ausmoss/21...
# 2608  https://id.biodiversity.org.au/name/ausmoss/21...
# 2609  https://id.biodiversity.org.au/name/ausmoss/14...
# 2610  https://id.biodiversity.org.au/name/ausmoss/13...
# 2611  https://id.biodiversity.org.au/name/ausmoss/14...
#
#                                           accordingToID  \
# 0     https://id.biodiversity.org.au/reference/ausmo...
# 1     https://id.biodiversity.org.au/reference/ausmo...
# 2     https://id.biodiversity.org.au/reference/ausmo...
# 3     https://id.biodiversity.org.au/reference/ausmo...
# 4     https://id.biodiversity.org.au/reference/ausmo...
# ...                                                 ...
# 2607  https://id.biodiversity.org.au/reference/ausmo...
# 2608  https://id.biodiversity.org.au/reference/ausmo...
# 2609  https://id.biodiversity.org.au/reference/ausmo...
# 2610  https://id.biodiversity.org.au/reference/ausmo...
# 2611  https://id.biodiversity.org.au/reference/ausmo...
#
#                                                parentID remarks
# 0                                                   NaN     NaN
# 1     https://id.biodiversity.org.au/instance/ausmos...     NaN
# 2     https://id.biodiversity.org.au/instance/ausmos...     NaN
# 3     https://id.biodiversity.org.au/instance/ausmos...     NaN
# 4     https://id.biodiversity.org.au/instance/ausmos...     NaN
# ...                                                 ...     ...
# 2607  https://id.biodiversity.org.au/instance/ausmos...     NaN
# 2608  https://id.biodiversity.org.au/instance/ausmos...     NaN
# 2609  https://id.biodiversity.org.au/instance/ausmos...     NaN
# 2610  https://id.biodiversity.org.au/instance/ausmos...     NaN
# 2611  https://id.biodiversity.org.au/instance/ausmos...     NaN
#
# [2612 rows x 5 columns]

# %% [markdown]
# ### Reference

# %%
df_ref = df_taxa[['nameAccordingToID', 'nameAccordingTo']]
df_ref.drop_duplicates(inplace=True)
df_ref.rename(columns={'nameAccordingToID': 'ID', 'nameAccordingTo': 'citation'}, inplace=True)
df_ref
# Out:
# /tmp/ipykernel_2356/3187620901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ref.drop_duplicates(inplace=True)
# /tmp/ipykernel_2356/3187620901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ref.rename(columns={'nameAccordingToID': 'ID', 'nameAccordingTo': 'citation'}, inplace=True)
#                                                      ID  \
# 0     https://id.biodiversity.org.au/reference/ausmo...
# 1     https://id.biodiversity.org.au/reference/ausmo...
# 5     https://id.biodiversity.org.au/reference/ausmo...
# 6     https://id.biodiversity.org.au/reference/ausmo...
# 7     https://id.biodiversity.org.au/reference/ausmo...
# 10    https://id.biodiversity.org.au/reference/ausmo...
# 41    https://id.biodiversity.org.au/reference/ausmo...
# 68    https://id.biodiversity.org.au/reference/ausmo...
# 73    https://id.biodiversity.org.au/reference/ausmo...
# 196   https://id.biodiversity.org.au/reference/ausmo...
# 516   https://id.biodiversity.org.au/reference/ausmo...
# 834   https://id.biodiversity.org.au/reference/ausmo...
# 880   https://id.biodiversity.org.au/reference/ausmo...
# 1939  https://id.biodiversity.org.au/reference/ausmo...
# 2278  https://id.biodiversity.org.au/reference/ausmo...
# 2387  https://id.biodiversity.org.au/reference/ausmo...
# 3267  https://id.biodiversity.org.au/reference/ausmo...
#
#                                                citation
# 0     Klazenga, N. (2015), AusMoss: Catalogue of Aus...
# 1     Renzaglia, K.S., Villarreal, J.C. & Duff, R.J....
# 5                  CHAH (2011), Australian Plant Census
# 6                  CHAH (2010), Australian Plant Census
# 7     McCarthy, P.M. (2003), Catalogue of Australian...
# 10    Klazenga, N. (2023), Census of Australian Bryo...
# 41                 CHAH (2013), Australian Plant Census
# 68    Goffinet, B. & W.R. Buck (2017), Classificatio...
# 73    Klazenga, N. (2023), Census of Australian bryo...
# 196   Klazenga, N. (2019), Census of Australian bryo...
# 516   Klazenga, N. (2017), AusMoss: Catalogue of Aus...
# 834   Klazenga, N. (2018), AusMoss: Catalogue of Aus...
# 880   Klazenga, N. (2023), Census of Australian Bryo...
# 1939  Klazenga, N. (27 July 2021), Census of Austral...
# 2278  Klazenga, N. (September 2023), Census of Austr...
# 2387  Klazenga, N. (7 September 2020), Census of Aus...
# 3267            Schuster, R.M. (1972), Nova Hedwigia 22

# %% [markdown]
# ### Alias identifiers
#
# (HTTP identifiers break ChecklistBank)

# %%
# # taxon

# df_tax['ID'] = df_tax['ID'].str.replace('apni', 'ausmoss')
# df_tax['ID'] = df_tax['ID'].str.replace('https://id.biodiversity.org.au/instance/ausmoss/', 'ausmoss-taxon-')
# df_tax['nameID'] = df_tax['nameID'].str.replace('apni', 'ausmoss')
# df_tax['nameID'] = df_tax['nameID'].str.replace('https://id.biodiversity.org.au/name/ausmoss/', 'ausmoss-name-')
# df_tax['accordingToID'] = df_tax['accordingToID'].str.replace('apni', 'ausmoss')
# df_tax['accordingToID'] = df_tax['accordingToID'].str.replace('https://id.biodiversity.org.au/reference/ausmoss/', 'ausmoss-reference-')
# df_tax['parentID'] = df_tax['parentID'].str.replace('apni', 'ausmoss')
# df_tax['parentID'] = df_tax['parentID'].str.replace('https://id.biodiversity.org.au/instance/ausmoss/', 'ausmoss-taxon-')

# # normalise whitespace
# _RE_COMBINE_WHITESPACE = re.compile(r"\s+")

# remarks = []
# for index, row in df_tax.iterrows():
#     if isinstance(row['remarks'], str):
#         remarks.append(_RE_COMBINE_WHITESPACE.sub(" ", row['remarks']).strip())
#     else:
#         remarks.append(np.NaN)

# df_tax['remarks'] = remarks

# df_tax

# %%
# # name

# df_nam.rename(columns={
#         'scientificNameID': 'ID', 
#         'taxonRank': 'rank', 
#         'genericName': 'genus', 
#         'nomenclaturalStatus': 'status'
#     }, inplace=True)
# df_nam.drop(columns=['originalNameUsageID', 'originalNameUsage'], inplace=True)

# df_nam['ID'] = df_nam['ID'].str.replace('apni', 'ausmoss')
# df_nam['ID'] = df_nam['ID'].str.replace('https://id.biodiversity.org.au/name/ausmoss/', 'ausmoss-name-')
# df_nam

# %%
# # namerelation

# df_namerel['nameID'] = df_namerel['nameID'].str.replace('apni', 'ausmoss-name-')
# df_namerel['nameID'] = df_namerel['nameID'].str.replace('https://id.biodiversity.org.au/name/ausmoss/', 'ausmoss')
# df_namerel['relatedNameID'] = df_namerel['relatedNameID'].str.replace('apni', 'ausmoss')
# df_namerel['relatedNameID'] = df_namerel['relatedNameID'].str.replace('https://id.biodiversity.org.au/name/ausmoss/', 'ausmoss-name-')
# df_namerel

# %%
# # synonym 

# df_syn['ID'] = df_syn['ID'].str.replace('apni', 'ausmoss')
# df_syn['ID'] = df_syn['ID'].str.replace('https://id.biodiversity.org.au/instance/ausmoss/', 'ausmoss-synonym-')
# df_syn['taxonID'] = df_syn['taxonID'].str.replace('apni', 'ausmoss')
# df_syn['taxonID'] = df_syn['taxonID'].str.replace('https://id.biodiversity.org.au/instance/ausmoss/', 'ausmoss-taxon-')
# df_syn['nameID'] = df_syn['nameID'].str.replace('apni', 'ausmoss')
# df_syn['nameID'] = df_syn['nameID'].str.replace('https://id.biodiversity.org.au/name/ausmoss/', 'ausmoss-name-')

# df_syn

# %%
# # reference

# df_ref['ID'] = df_ref['ID'].str.replace('apni', 'ausmoss')
# df_ref['ID'] = df_ref['ID'].str.replace('https://id.biodiversity.org.au/reference/', 'ausmoss-reference-')
# df_ref

# %% [markdown]
# ### Remove duplicates

# %%
print(df_tax.shape)
df_tax.drop_duplicates(inplace=True)
print(df_tax.shape)

print(df_nam.shape)
df_nam.drop_duplicates(inplace=True)
print(df_nam.shape)
# Out:
# (2612, 5)
# (2612, 5)
# (7280, 12)
# (6205, 12)

# %% [markdown]
# ### Create CoLDP

# %%
import os
from zipfile import ZipFile

os.chdir('/home/niels/code/jupyter-notebooks/nsl_export/coldp/' + group)

df_tax.to_csv('taxon.tsv', sep='\t', index=False)
df_syn.to_csv('synonym.tsv', sep='\t', index=False)
df_nam.to_csv('name.tsv', sep='\t', index=False)
df_name_relationships.to_csv('dwc_basionyms.tsv', sep='\t', index=False)
df_namerel.to_csv('namerelation.tsv', sep='\t', index=False)
df_higher.to_csv('dwc_higherclassification.tsv', sep='\t', index=False)
df_dwc_syn.to_csv('dwc_synonym.tsv', sep='\t', index=False)
df_ref.to_csv('reference.tsv', sep='\t', index=False)

with ZipFile('nsl_' + group + '_coldp.zip', 'w') as zipobj:
    zipobj.write('taxon.tsv')
    zipobj.write('name.tsv')
    zipobj.write('synonym.tsv')
    zipobj.write('namerelation.tsv')
    zipobj.write('reference.tsv')

os.chdir('/home/niels/code/jupyter-notebooks/nsl_export')
