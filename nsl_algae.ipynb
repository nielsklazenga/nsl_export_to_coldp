# %% [markdown]
# # NSL export to CoLDP: algae

# %%
import pandas as pd
import numpy as np

namefile = 'data/algae/AANI-names-2023-06-24-3420.csv'
taxonfile = 'data/algae/AAL-taxon-2023-06-24-3606.csv'

# %% [markdown]
# ### Names

# %%
df_names = pd.read_csv(namefile)

# Remove excess columns
columns = [
    'scientificNameID', 
    'nameAccordingToID', 
    'taxonRank', 
    'scientificName', 
    'genericName', 
    'specificEpithet', 
    'infraspecificEpithet', 
    'scientificNameAuthorship', 
    'nomenclaturalStatus',
    'originalNameUsageID', 
    'originalNameUsage'
]

df1 = df_names[columns]

# Instance ID is in nameAccordingToID for reasons unfathomable; rename to taxonID
df1 = df1.rename(columns={'nameAccordingToID': 'taxonID'})

# Filter for names with originalNameUsage
# Replace instance IDs in originalNameUsageID with scientificNameIDs; we will not need taxonID anymore after that
df2 = df1[~df1['originalNameUsageID'].isna()].merge(df1, how='left', left_on='originalNameUsageID', right_on='taxonID')[[
    'scientificNameID_x', 
    'taxonRank_x', 
    'scientificName_x', 
    'genericName_x', 
    'specificEpithet_x', 
    'infraspecificEpithet_x', 
    'scientificNameAuthorship_x', 
    'nomenclaturalStatus_x', 
    'scientificNameID_y', 
    'scientificName_y'
]]

column_mappings = {
    'scientificNameID_x': 'scientificNameID',
    'scientificName_x': 'scientificName',
    'taxonRank_x': 'taxonRank',
    'genericName_x': 'genericName',
    'specificEpithet_x': 'specificEpithet',
    'infraspecificEpithet_x': 'infraspecificEpithet',
    'scientificNameAuthorship_x': 'scientificNameAuthorship',
    'nomenclaturalStatus_x': 'nomenclaturalStatus',
    'scientificNameID_y': 'originalNameUsageID',
    'scientificName_y': 'originalNameUsage'
}

df2 = df2.rename(columns=column_mappings)

# Filter for names without originalNameUsage
df3 = df_names[df_names['originalNameUsage'].isna()][columns]
df3.drop(columns=['nameAccordingToID'], inplace=True)

# Merge dataframes
df5 = pd.concat([df2, df3])
df5 = df5.sort_values(by='scientificName')

# Make taxonRank lowercase
df5['taxonRank'] = df5['taxonRank'].str.lower()

# Map Latin rank names to less wankerish English ones
ranks = {
    'genus': 'genus',
    'species': 'species',
    'familia': 'family',
    'subfamilia': 'subfamily',
    'ordo': 'order',
    'subordo': 'suborder',
    'superordo': 'superorder',
    'subspecies': 'subspecies',
    'classis': 'class',
    'subclassis': 'subclass',
    'subdivision': 'subphylum',
    'subbdivision': 'subphylum',
    'varietas': 'variety',
    'subvarietas': 'subvariety',
    'subgenus': 'subgenus',
    'superspecies': 'superspecies',
    'forma': 'form',
    'division': 'phylum',
    'regnum': 'kingdom',
    'special form': 'special form',
    'sectio': 'section',
    'regio': 'domain',
    '[unknown]': '[unknown]',
    '[unranked]': '[unranked]'
}

taxon_ranks = []
uninomials = []
generic_names = []
for index, row in df5.iterrows():
    taxon_ranks.append(ranks[row['taxonRank']])

    uninomial = np.NaN
    generic_name = row['genericName']

    if not isinstance(row['genericName'], str):
        if not isinstance(row['scientificNameAuthorship'], str):
            uninomial = row['scientificName']
        else:
            uninomial = row['scientificName'][0:len(row['scientificName'])-len(row['scientificNameAuthorship'])-1]

    if row['taxonRank'] == 'genus':
        uninomial = row['genericName']
        generic_name = np.NaN

    uninomials.append(uninomial)
    generic_names.append(generic_name)

df5['taxonRank'] = taxon_ranks
df5['genericName'] = generic_names
df5['uninomial'] = uninomials

# Add nomenclaturalCode; 'ICN' in GBIF vocab. but 'botanical' in CoLDP
df5['code'] = 'botanical'

df5 = df5[[
    'scientificNameID', 
    'taxonRank', 
    'scientificName', 
    'uninomial',
    'genericName', 
    'specificEpithet', 
    'infraspecificEpithet', 
    'scientificNameAuthorship', 
    'code', 
    'nomenclaturalStatus', 
    'originalNameUsageID', 
    'originalNameUsage'
  ]]

df_nam = df5
df5
# Out:
#                                         scientificNameID taxonRank  \
# 1      https://id.biodiversity.org.au/name/algae/2008...     genus
# 0      https://id.biodiversity.org.au/name/algae/2008...   species
# 19691  https://id.biodiversity.org.au/name/algae/2008...    family
# 5198   https://id.biodiversity.org.au/name/algae/2000...     genus
# 1268   https://id.biodiversity.org.au/name/algae/2000...   species
# ...                                                  ...       ...
# 9619   https://id.biodiversity.org.au/name/algae/2001...   species
# 9618   https://id.biodiversity.org.au/name/algae/2001...      form
# 20097  https://id.biodiversity.org.au/name/algae/2000...     class
# 20157  https://id.biodiversity.org.au/name/algae/2000...     order
# 20079  https://id.biodiversity.org.au/name/algae/2000...    phylum
#
#                                           scientificName  \
# 1                                   Acanthoceras Honigm.
# 0               Acanthoceras zachariasii (Brun) Simonsen
# 19691                                  Acanthocerataceae
# 5198                       Acanthococcus Hook.f. & Harv.
# 1268        Acanthococcus acicularis (J.Agardh) J.Agardh
# ...                                                  ...
# 9619                    [Genus Not Recorded] lichenoides
# 9618   [Genus Not Recorded] lichenoides f. coronopifolia
# 20097                         [Uncertain Class Affinity]
# 20157                         [Uncertain Order Affinity]
# 20079                                 [Unknown Division]
#
#                         uninomial           genericName specificEpithet  \
# 1                    Acanthoceras                   NaN             NaN
# 0                             NaN          Acanthoceras     zachariasii
# 19691           Acanthocerataceae                   NaN             NaN
# 5198                Acanthococcus                   NaN             NaN
# 1268                          NaN         Acanthococcus      acicularis
# ...                           ...                   ...             ...
# 9619                          NaN  [Genus Not Recorded]     lichenoides
# 9618                          NaN  [Genus Not Recorded]     lichenoides
# 20097  [Uncertain Class Affinity]                   NaN             NaN
# 20157  [Uncertain Order Affinity]                   NaN             NaN
# 20079          [Unknown Division]                   NaN             NaN
#
#       infraspecificEpithet scientificNameAuthorship       code  \
# 1                      NaN                  Honigm.  botanical
# 0                      NaN          (Brun) Simonsen  botanical
# 19691                  NaN                      NaN  botanical
# 5198                   NaN          Hook.f. & Harv.  botanical
# 1268                   NaN      (J.Agardh) J.Agardh  botanical
# ...                    ...                      ...        ...
# 9619                   NaN                      NaN  botanical
# 9618         coronopifolia                      NaN  botanical
# 20097                  NaN                      NaN  botanical
# 20157                  NaN                      NaN  botanical
# 20079                  NaN                      NaN  botanical
#
#       nomenclaturalStatus                                originalNameUsageID  \
# 1                     NaN                                                NaN
# 0                     NaN  https://id.biodiversity.org.au/name/algae/2008...
# 19691                 NaN                                                NaN
# 5198                  NaN                                                NaN
# 1268                  NaN  https://id.biodiversity.org.au/name/algae/2001...
# ...                   ...                                                ...
# 9619                  NaN                                                NaN
# 9618                  NaN                                                NaN
# 20097                 NaN                                                NaN
# 20157                 NaN                                                NaN
# 20079                 NaN                                                NaN
#
#                      originalNameUsage
# 1                                  NaN
# 0             Attheya zachariasii Brun
# 19691                              NaN
# 5198                               NaN
# 1268   Cystoclonium aciculare J.Agardh
# ...                                ...
# 9619                               NaN
# 9618                               NaN
# 20097                              NaN
# 20157                              NaN
# 20079                              NaN
#
# [20375 rows x 12 columns]

# %% [markdown]
# ### Name relations

# %%
df_name_relationships = df5[~df5['originalNameUsageID'].isna()][['scientificNameID', 'scientificName', 'originalNameUsageID', 'originalNameUsage']]

df_namerel = df_name_relationships[['scientificNameID', 'originalNameUsageID']]
df_namerel['type'] = 'basionym'
df_namerel.rename(columns={'scientificNameID': 'nameID', 'originalNameUsageID': 'relatedNameID'}, inplace=True)

# Remove originalNameUsage columns from Names
drop_columns = [
    'originalNameUsageID',
    'originalNameUsage'
]

rename_columns = {
    'scientificNameID': 'ID',
    'taxonRank': 'rank',
    'scientificName': 'scientificName',
    'genericName': 'genus',
    'scientificNameAuthorship': 'authorship',
    'nomenclaturalStatus': 'status'
}

df5.drop(columns=drop_columns, inplace=True)
df5.rename(columns=rename_columns, inplace=True)
# Out:
# /tmp/ipykernel_311174/3173867388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_namerel['type'] = 'basionym'
# /tmp/ipykernel_311174/3173867388.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_namerel.rename(columns={'scientificNameID': 'nameID', 'originalNameUsageID': 'relatedNameID'}, inplace=True)

# %% [markdown]
# ### Taxa

# %%
# Read Taxon export into dataframe
df_taxa = pd.read_csv(taxonfile)
df_taxa = df_taxa[df_taxa['nameType'] == 'scientific']

# Create dataframe with IDs
# This is used later to replace tree element IDs (in taxonID) with instance IDs (in taxonConceptID)
df_id = df_taxa[['taxonID', 'taxonConceptID']]

# %%
# Filter on accepted names; these are the taxa
df_tax = df_taxa[df_taxa['taxonomicStatus'] == 'accepted']

# Replace tree element IDs in taxonID with instance IDs (see above)
df_tax['taxonID'] = df_tax['taxonConceptID']

# Replace tree element IDs in parentNameUsageID with instance IDs
df_tax = df_tax.merge(df_id, how='left', left_on='parentNameUsageID', right_on='taxonID')
df_tax['parentNameUsageID'] = df_tax['taxonConceptID_y']
df_tax.drop(columns=['taxonID_y', 'taxonConceptID_y'], inplace=True)
df_tax.rename(columns={'taxonID_x': 'taxonID', 'taxonConceptID_x': 'taxonConceptID'}, inplace=True)

df_tax = df_tax[['taxonID',
 'scientificNameID',
 'scientificName',
 'scientificNameAuthorship',
 'nameAccordingTo',
 'nameAccordingToID',
 'parentNameUsageID',
 'taxonRank',
 'taxonRankSortOrder',
 'kingdom',
 'class',
 'subclass',
 'family',
 'taxonConceptID',
 'taxonRemarks',
 'higherClassification'
]]

# Translate ranks into English
df_tax['taxonRank'] = df_tax['taxonRank'].str.lower()
ranks = {
    'genus': 'genus',
    'species': 'species',
    'familia': 'family',
    'subfamilia': 'subfamily',
    'ordo': 'order',
    'subordo': 'suborder',
    'superordo': 'superorder',
    'subspecies': 'subspecies',
    'classis': 'class',
    'subclassis': 'subclass',
    'subdivision': 'subphylum',
    'subbdivision': 'subphylum',
    'varietas': 'variety',
    'subgenus': 'subgenus',
    'superspecies': 'superspecies',
    'forma': 'form',
    'division': 'phylum',
    'regnum': 'kingdom',
    'special form': 'special form',
    'sectio': 'section',
    'regio': 'domain',
    '[unknown]': '[unknown]'
}

taxon_ranks = []
for index, row in df_tax.iterrows():
    taxon_ranks.append(ranks[row['taxonRank']])

df_tax['taxonRank'] = taxon_ranks
# Out:
# /tmp/ipykernel_311174/2562605175.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tax['taxonID'] = df_tax['taxonConceptID']

# %% [markdown]
# #### Higher classification

# %%
# Create dictionary with higher taxa from instance ID
def get_higher_taxa(id, higher={}):
    row = df_tax.loc[df_tax['taxonID'] == id]

    if len(row) > 0:
        parent = row[[
            'taxonRank', 
            'scientificName', 
            'scientificNameAuthorship', 
            'parentNameUsageID']].to_dict(orient='records')[0]
        
        if isinstance(parent['scientificNameAuthorship'], str):
            higher[parent['taxonRank']] = parent['scientificName'][0:len(parent['scientificName'])-len(parent['scientificNameAuthorship'])-1]
        else:
            higher[parent['taxonRank']] = parent['scientificName']

        if isinstance(parent['parentNameUsageID'], str):
            return get_higher_taxa(parent['parentNameUsageID'], higher)
        else:
            return higher
    else:
        return higher

# %%
# Create higher classification
def create_higher_classification(id):
    higher = get_higher_taxa(id, {})
    keys = list(higher.keys())

    hcl = {}

    hcl['taxonID'] = id
    hcl['species'] = higher['species'] if 'species' in keys else np.NaN
    hcl['section'] = higher['section'] if 'section' in keys else np.NaN
    hcl['subgenus'] = higher['subgenus'] if 'subgenus' in keys else np.NaN
    hcl['genus'] = higher['genus'] if 'genus' in keys else np.NaN
    hcl['subtribe'] = higher['subtribe'] if 'subtribe' in keys else np.NaN
    hcl['tribe'] = higher['tribe'] if 'tribe' in keys else np.NaN
    hcl['subfamily'] = higher['subfamily'] if 'subfamily' in keys else np.NaN
    hcl['family'] = higher['family'] if 'family' in keys else np.NaN
    hcl['superfamily'] = higher['superfamily'] if 'superfamily' in keys else np.NaN
    hcl['suborder'] = higher['suborder'] if 'suborder' in keys else np.NaN
    hcl['order'] = higher['order'] if 'order' in keys else np.NaN
    hcl['subclass'] = higher['subclass'] if 'subclass' in keys else np.NaN
    hcl['class'] = higher['class'] if 'class' in keys else np.NaN
    hcl['subphylum'] = higher['subphylum'] if 'subphylum' in keys else np.NaN
    hcl['phylum'] = higher['phylum'] if 'phylum' in keys else np.NaN
    hcl['kingdom'] = higher['kingdom'] if 'kingdom' in keys else np.NaN

    cl = list(higher.values())
    for i in range(len(cl) // 2):
        cl[i], cl[-1 - i] = cl[-1 - i], cl[i]

    hcl['classification'] = ' | '.join(cl)

    return hcl

create_higher_classification('https://id.biodiversity.org.au/instance/lichen/30043034')
# Out:
# {'taxonID': 'https://id.biodiversity.org.au/instance/lichen/30043034',
#  'species': nan,
#  'section': nan,
#  'subgenus': nan,
#  'genus': nan,
#  'subtribe': nan,
#  'tribe': nan,
#  'subfamily': nan,
#  'family': nan,
#  'superfamily': nan,
#  'suborder': nan,
#  'order': nan,
#  'subclass': nan,
#  'class': nan,
#  'subphylum': nan,
#  'phylum': nan,
#  'kingdom': nan,
#  'classification': ''}

# %%
cl = []
for index, row in df_tax.iterrows():
    cl.append(create_higher_classification(row['taxonID']))

df_higher = pd.DataFrame.from_dict(cl)

df_higher = df_higher.merge(df_tax[['taxonID', 'scientificName', 'taxonRank']], how='left', left_on='taxonID', right_on='taxonID')

df_higher = df_higher[['taxonID',
 'scientificName',
 'taxonRank',
 'kingdom',
 'phylum',
 'subphylum',
 'class',
 'subclass',
 'order',
 'suborder',
 'superfamily',
 'family',
 'tribe',
 'subfamily',
 'subtribe',
 'genus',
 'subgenus',
 'section',
 'species',
 'classification']]

df_higher.rename(columns={'classification': 'higherClassification'}, inplace=True)

df_higher
# Out:
#                                                 taxonID  \
# 0     https://id.biodiversity.org.au/instance/algae/...
# 1     https://id.biodiversity.org.au/instance/algae/...
# 2     https://id.biodiversity.org.au/instance/algae/...
# 3     https://id.biodiversity.org.au/instance/algae/...
# 4     https://id.biodiversity.org.au/instance/algae/...
# ...                                                 ...
# 3006  https://id.biodiversity.org.au/instance/algae/...
# 3007  https://id.biodiversity.org.au/instance/algae/...
# 3008  https://id.biodiversity.org.au/instance/algae/...
# 3009  https://id.biodiversity.org.au/instance/algae/...
# 3010  https://id.biodiversity.org.au/instance/algae/...
#
#                      scientificName taxonRank    kingdom           phylum  \
# 0                         Eukaryota   kingdom  Eukaryota              NaN
# 1                          Anthozoa    phylum  Eukaryota         Anthozoa
# 2                        Coraliidae    family  Eukaryota         Anthozoa
# 3                   Bacillariophyta    phylum  Eukaryota  Bacillariophyta
# 4                 Bacillariophyceae     class  Eukaryota  Bacillariophyta
# ...                             ...       ...        ...              ...
# 3006                   Vaucheriales     order  Eukaryota      Xanthophyta
# 3007                  Vaucheriaceae    family  Eukaryota      Xanthophyta
# 3008                  Vaucheria DC.     genus  Eukaryota      Xanthophyta
# 3009  Vaucheria caloundrensis Cribb   species  Eukaryota      Xanthophyta
# 3010    Vaucheria velutina C.Agardh   species  Eukaryota      Xanthophyta
#
#       subphylum              class subclass         order  suborder  \
# 0           NaN                NaN      NaN           NaN       NaN
# 1           NaN                NaN      NaN           NaN       NaN
# 2           NaN                NaN      NaN           NaN       NaN
# 3           NaN                NaN      NaN           NaN       NaN
# 4           NaN  Bacillariophyceae      NaN           NaN       NaN
# ...         ...                ...      ...           ...       ...
# 3006        NaN      Xanthophyceae      NaN  Vaucheriales       NaN
# 3007        NaN      Xanthophyceae      NaN  Vaucheriales       NaN
# 3008        NaN      Xanthophyceae      NaN  Vaucheriales       NaN
# 3009        NaN      Xanthophyceae      NaN  Vaucheriales       NaN
# 3010        NaN      Xanthophyceae      NaN  Vaucheriales       NaN
#
#       superfamily         family  tribe  subfamily  subtribe      genus  \
# 0             NaN            NaN    NaN        NaN       NaN        NaN
# 1             NaN            NaN    NaN        NaN       NaN        NaN
# 2             NaN     Coraliidae    NaN        NaN       NaN        NaN
# 3             NaN            NaN    NaN        NaN       NaN        NaN
# 4             NaN            NaN    NaN        NaN       NaN        NaN
# ...           ...            ...    ...        ...       ...        ...
# 3006          NaN            NaN    NaN        NaN       NaN        NaN
# 3007          NaN  Vaucheriaceae    NaN        NaN       NaN        NaN
# 3008          NaN  Vaucheriaceae    NaN        NaN       NaN  Vaucheria
# 3009          NaN  Vaucheriaceae    NaN        NaN       NaN  Vaucheria
# 3010          NaN  Vaucheriaceae    NaN        NaN       NaN  Vaucheria
#
#       subgenus  section                  species  \
# 0          NaN      NaN                      NaN
# 1          NaN      NaN                      NaN
# 2          NaN      NaN                      NaN
# 3          NaN      NaN                      NaN
# 4          NaN      NaN                      NaN
# ...        ...      ...                      ...
# 3006       NaN      NaN                      NaN
# 3007       NaN      NaN                      NaN
# 3008       NaN      NaN                      NaN
# 3009       NaN      NaN  Vaucheria caloundrensis
# 3010       NaN      NaN       Vaucheria velutina
#
#                                    higherClassification
# 0                                             Eukaryota
# 1                                  Eukaryota | Anthozoa
# 2                     Eukaryota | Anthozoa | Coraliidae
# 3                           Eukaryota | Bacillariophyta
# 4       Eukaryota | Bacillariophyta | Bacillariophyceae
# ...                                                 ...
# 3006  Eukaryota | Xanthophyta | Xanthophyceae | Vauc...
# 3007  Eukaryota | Xanthophyta | Xanthophyceae | Vauc...
# 3008  Eukaryota | Xanthophyta | Xanthophyceae | Vauc...
# 3009  Eukaryota | Xanthophyta | Xanthophyceae | Vauc...
# 3010  Eukaryota | Xanthophyta | Xanthophyceae | Vauc...
#
# [3011 rows x 20 columns]

# %% [markdown]
# #### Synonyms

# %%
# Filter on synonyms
df_syn = df_taxa[df_taxa['taxonomicStatus'].isin(['synonym', 'nomenclatural synonym', 'taxonomic synonym']) & ~df_taxa['acceptedNameUsageID'].isna()][[
    'taxonID',
    'scientificNameID',
    'scientificName',
    'acceptedNameUsageID',
    'acceptedNameUsage',
    'taxonomicStatus'
]]

# Replace tree element IDs in acceptedNameUsageID with instance IDs
df_syn = df_syn.merge(df_id, how='left', left_on='acceptedNameUsageID', right_on='taxonID')

df_syn.drop(columns=['acceptedNameUsageID', 'taxonID_y'], inplace=True)
df_syn.rename(columns={
    'taxonID_x': 'ID',
    'taxonConceptID': 'taxonID',
    'scientificNameID': 'nameID'    
}, inplace=True)
df_syn = df_syn[['ID', 'taxonID', 'nameID', 'scientificName', 'acceptedNameUsage', 'taxonomicStatus']]

# Get accepted names
df_dwc_syn = df_syn.merge(df_tax[['taxonID', 'scientificName']], left_on='taxonID', right_on='taxonID')

df_dwc_syn.drop(columns=['taxonID', 'nameID', 'acceptedNameUsage'], inplace=True)

df_dwc_syn.rename(columns={
    'ID': 'taxonID',
    'scientificName_x': 'scientificName',
    'scientificName_y': 'acceptedNameUsage'
}, inplace=True)

df_syn.drop(columns=['scientificName', 'acceptedNameUsage', 'taxonomicStatus'], inplace=True)

df_syn
# Out:
#                                                      ID  \
# 0     https://id.biodiversity.org.au/instance/algae/...
# 1     https://id.biodiversity.org.au/instance/algae/...
# 2     https://id.biodiversity.org.au/instance/algae/...
# 3     https://id.biodiversity.org.au/instance/algae/...
# 4     https://id.biodiversity.org.au/instance/algae/...
# ...                                                 ...
# 1101  https://id.biodiversity.org.au/instance/algae/...
# 1102  https://id.biodiversity.org.au/instance/algae/...
# 1103  https://id.biodiversity.org.au/instance/algae/...
# 1104  https://id.biodiversity.org.au/instance/algae/...
# 1105  https://id.biodiversity.org.au/instance/algae/...
#
#                                                 taxonID  \
# 0     http://id.biodiversity.org.au/instance/algae/2...
# 1     http://id.biodiversity.org.au/instance/algae/2...
# 2     http://id.biodiversity.org.au/instance/algae/2...
# 3     http://id.biodiversity.org.au/instance/algae/2...
# 4     http://id.biodiversity.org.au/instance/algae/2...
# ...                                                 ...
# 1101  http://id.biodiversity.org.au/instance/algae/2...
# 1102  http://id.biodiversity.org.au/instance/algae/2...
# 1103  http://id.biodiversity.org.au/instance/algae/2...
# 1104  http://id.biodiversity.org.au/instance/algae/2...
# 1105  https://id.biodiversity.org.au/instance/algae/...
#
#                                                  nameID
# 0     https://id.biodiversity.org.au/name/algae/2015...
# 1     https://id.biodiversity.org.au/name/algae/2015...
# 2     https://id.biodiversity.org.au/name/algae/2015...
# 3     https://id.biodiversity.org.au/name/algae/2015...
# 4     https://id.biodiversity.org.au/name/algae/2008...
# ...                                                 ...
# 1101  https://id.biodiversity.org.au/name/algae/2000...
# 1102  https://id.biodiversity.org.au/name/algae/2000...
# 1103  https://id.biodiversity.org.au/name/algae/2000...
# 1104  https://id.biodiversity.org.au/name/algae/2001...
# 1105  https://id.biodiversity.org.au/name/algae/2001...
#
# [1106 rows x 3 columns]

# %% [markdown]
# #### Remove excess columns

# %%
df_tax = df_tax[['taxonID',
 'scientificNameID',
 'nameAccordingToID',
 'parentNameUsageID',
 'taxonRemarks']]

df_tax.rename(columns={
    'taxonID': 'ID',
    'scientificNameID': 'nameID',
    'nameAccordingToID': 'accordingToID',
    'parentNameUsageID': 'parentID',
    'taxonRemarks': 'remarks'
}, inplace=True)

df_tax
# Out:
#                                                      ID  \
# 0     https://id.biodiversity.org.au/instance/algae/...
# 1     https://id.biodiversity.org.au/instance/algae/...
# 2     https://id.biodiversity.org.au/instance/algae/...
# 3     https://id.biodiversity.org.au/instance/algae/...
# 4     https://id.biodiversity.org.au/instance/algae/...
# ...                                                 ...
# 3006  https://id.biodiversity.org.au/instance/algae/...
# 3007  https://id.biodiversity.org.au/instance/algae/...
# 3008  https://id.biodiversity.org.au/instance/algae/...
# 3009  https://id.biodiversity.org.au/instance/algae/...
# 3010  https://id.biodiversity.org.au/instance/algae/...
#
#                                                  nameID  \
# 0     https://id.biodiversity.org.au/name/algae/2020...
# 1     https://id.biodiversity.org.au/name/algae/2001...
# 2     https://id.biodiversity.org.au/name/algae/2001...
# 3     https://id.biodiversity.org.au/name/algae/2016...
# 4     https://id.biodiversity.org.au/name/algae/2015...
# ...                                                 ...
# 3006  https://id.biodiversity.org.au/name/algae/2000...
# 3007  https://id.biodiversity.org.au/name/algae/2009...
# 3008  https://id.biodiversity.org.au/name/algae/2000...
# 3009  https://id.biodiversity.org.au/name/algae/2001...
# 3010  https://id.biodiversity.org.au/name/algae/2001...
#
#                                           accordingToID  \
# 0     https://id.biodiversity.org.au/reference/aani/...
# 1     https://id.biodiversity.org.au/reference/aani/...
# 2     https://id.biodiversity.org.au/reference/aani/...
# 3     https://id.biodiversity.org.au/reference/aani/...
# 4     https://id.biodiversity.org.au/reference/aani/...
# ...                                                 ...
# 3006  https://id.biodiversity.org.au/reference/aani/...
# 3007  https://id.biodiversity.org.au/reference/aani/...
# 3008  https://id.biodiversity.org.au/reference/aani/...
# 3009  https://id.biodiversity.org.au/reference/aani/...
# 3010  https://id.biodiversity.org.au/reference/aani/...
#
#                                                parentID  remarks
# 0                                                   NaN      NaN
# 1     https://id.biodiversity.org.au/instance/algae/...      NaN
# 2     https://id.biodiversity.org.au/instance/algae/...      NaN
# 3     https://id.biodiversity.org.au/instance/algae/...      NaN
# 4     https://id.biodiversity.org.au/instance/algae/...      NaN
# ...                                                 ...      ...
# 3006  https://id.biodiversity.org.au/instance/algae/...      NaN
# 3007  https://id.biodiversity.org.au/instance/algae/...      NaN
# 3008  https://id.biodiversity.org.au/instance/algae/...      NaN
# 3009  https://id.biodiversity.org.au/instance/algae/...      NaN
# 3010  https://id.biodiversity.org.au/instance/algae/...      NaN
#
# [3011 rows x 5 columns]

# %% [markdown]
# ### Reference

# %%
df_ref = df_taxa[['nameAccordingToID', 'nameAccordingTo']]
df_ref.drop_duplicates(inplace=True)
df_ref.rename(columns={'nameAccordingToID': 'ID', 'nameAccordingTo': 'citation'}, inplace=True)
df_ref
# Out:
# /tmp/ipykernel_311174/3187620901.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ref.drop_duplicates(inplace=True)
# /tmp/ipykernel_311174/3187620901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ref.rename(columns={'nameAccordingToID': 'ID', 'nameAccordingTo': 'citation'}, inplace=True)
#                                                      ID  \
# 0     https://id.biodiversity.org.au/reference/aani/...
# 8     https://id.biodiversity.org.au/reference/aani/...
# 10    https://id.biodiversity.org.au/reference/aani/...
# 16    https://id.biodiversity.org.au/reference/aani/...
# 35    https://id.biodiversity.org.au/reference/aani/...
# 41    https://id.biodiversity.org.au/reference/aani/...
# 82    https://id.biodiversity.org.au/reference/aani/...
# 92    https://id.biodiversity.org.au/reference/aani/...
# 97    https://id.biodiversity.org.au/reference/aani/...
# 155   https://id.biodiversity.org.au/reference/aani/...
# 414   https://id.biodiversity.org.au/reference/aani/...
# 415   https://id.biodiversity.org.au/reference/aani/...
# 419   https://id.biodiversity.org.au/reference/aani/...
# 490   https://id.biodiversity.org.au/reference/aani/...
# 597   https://id.biodiversity.org.au/reference/aani/...
# 603   https://id.biodiversity.org.au/reference/aani/...
# 604   https://id.biodiversity.org.au/reference/aani/...
# 649   https://id.biodiversity.org.au/reference/aani/...
# 692   https://id.biodiversity.org.au/reference/aani/...
# 736   https://id.biodiversity.org.au/reference/aani/...
# 837   https://id.biodiversity.org.au/reference/aani/...
# 953   https://id.biodiversity.org.au/reference/aani/...
# 1452  https://id.biodiversity.org.au/reference/aani/...
# 1482  https://id.biodiversity.org.au/reference/aani/...
# 1486  https://id.biodiversity.org.au/reference/aani/...
# 1757  https://id.biodiversity.org.au/reference/aani/...
# 1759  https://id.biodiversity.org.au/reference/aani/...
# 1760  https://id.biodiversity.org.au/reference/aani/...
# 1763  https://id.biodiversity.org.au/reference/aani/...
# 1764  https://id.biodiversity.org.au/reference/aani/...
# 1791  https://id.biodiversity.org.au/reference/aani/...
# 1793  https://id.biodiversity.org.au/reference/aani/...
# 1795  https://id.biodiversity.org.au/reference/aani/...
# 1796  https://id.biodiversity.org.au/reference/aani/...
# 1939  https://id.biodiversity.org.au/reference/aani/...
# 1948  https://id.biodiversity.org.au/reference/aani/...
# 2020  https://id.biodiversity.org.au/reference/aani/...
# 2063  https://id.biodiversity.org.au/reference/aani/...
# 2234  https://id.biodiversity.org.au/reference/aani/...
# 2368  https://id.biodiversity.org.au/reference/aani/...
# 2613  https://id.biodiversity.org.au/reference/aani/...
# 2722  https://id.biodiversity.org.au/reference/aani/...
# 2813  https://id.biodiversity.org.au/reference/aani/...
# 2882  https://id.biodiversity.org.au/reference/aani/...
# 2890  https://id.biodiversity.org.au/reference/aani/...
#
#                                                citation
# 0     Algal Subcommittee (2019), CHAH Algal Subcommi...
# 8     Guiry, M.D. & Guiry, G M. (2021), -. Algaebase...
# 10    McCarthy, P. (2012), Census of Australian Mari...
# 16    Algal Subcommittee (2021), CHAH Algal Subcommi...
# 35    Guiry, M.D. & Guiry, G M. (2022), -. Algaebase...
# 41    Bukhtiyarova, L. (1995), New taxonomic combina...
# 82    ABRS (2022), Australian Algal Name Index Edn. ...
# 92    Entwisle, T.J. & Nairn, L. (2011), Census of F...
# 97           Smith, W. (1856), Syn. Brit. Diatomaceae 2
# 155   Algal Subcommittee (2022), CHAH Algal Subcommi...
# 414   Van Heurck, H.F. (1880), Synopsis des Diatomée...
# 415   Perag., H. & Perag., M. (1897), Diatomées Mari...
# 419   Lange-Bertalot, H. (1993), 85 Neue Taxa und üb...
# 490   Van Heurck, H.F. (1896), A treatise on the Dia...
# 597   Kuntze, O. (1891), Revisio Generum Plantarum. ...
# 603   Kützing, F.T. (1844), Die Kieselschaligen Baci...
# 604   Kuntze, O. (1891), Revisio Generum Plantarum. ...
# 649   Cleve, P.T. (1895), Synopsis of the naviculoid...
# 692   ABRS (2008), Australian Algal Name Index Edn. ...
# 736   De Toni, G.B. (1892), Ueber die Bacillarien-Ga...
# 837   Hustedt, F. (1957), Die Diatomeenflora des Flu...
# 953   ABRS (2023), Australian Algal Name Index Edn. ...
# 1452  Kützing, F.T. (1849), Species Algarum [i]-vi, ...
# 1482  Kraft, G.T. (2007), Marine Benthic Algae of Lo...
# 1486  ABRS (2011), Australian Algal Name Index Edn. ...
# 1757  Hansgirg, A. (1893), Prodromus der Algenflora ...
# 1759  Rabenhorst, L. (1863), Kryptogamen-Flora von S...
# 1760  De Toni, G.B. (1907), Sylloge Algarum omnium h...
# 1763  Rabenhorst, L. (1865), Algas phycochromaceas c...
# 1764  Lagerheim, N.G. (1883), Bidrag till Sveriges a...
# 1791  Drouet, F. & Daily, W. (1952), A synopsis of t...
# 1793             [No reference found in source data]. -
# 1795  Trevisan, V.B.A. (1848), Saggio di una monogra...
# 1796  Henfrey, A. (1856), Notes on some fresh-water ...
# 1939  McCarthy, P. (Comp.) (2012), Census of Austral...
# 1948  Paulsen, O. (1949), Observations on Dinoflagel...
# 2020  Wood, E.J.F. (1954), Dinoflagellates of the Au...
# 2063  Abé, T.H. (March 1967), The armoured Dinoflage...
# 2234  Throndsen, J., Hasle, G.R. & Tangen, K. (2003)...
# 2368               Taylor, F.J.R. (1976), Biblioth. Bot
# 2613  Gómez, F. (2013), Reinstatement of the dinofla...
# 2722  Gómez, F. (2021), Speciation and infrageneric ...
# 2813  Wood, E.J.F. (1963), Tech. Pap. Div. Fish. Oce...
# 2882  Balech, E. in Anderson, D.M., White, A.W. & Ba...
# 2890  Algal Subcommittee (2020), CHAH Algal Subcommi...

# %% [markdown]
# ### Create CoLDP

# %%
import os
from zipfile import ZipFile

os.chdir('/home/niels/code/jupyter-notebooks/nsl_export/coldp/algae')

df_tax.to_csv('taxon.tsv', sep='\t', index=False)
df_syn.to_csv('synonym.tsv', sep='\t', index=False)
df_nam.to_csv('name.tsv', sep='\t', index=False)
df_name_relationships.to_csv('dwc_basionyms.tsv', sep='\t', index=False)
df_namerel.to_csv('namerelation.tsv', sep='\t', index=False)
df_higher.to_csv('dwc_higherclassification.tsv', sep='\t', index=False)
df_dwc_syn.to_csv('dwc_synonym.tsv', sep='\t', index=False)
df_ref.to_csv('reference.tsv', sep='\t', index='False')

with ZipFile('nsl_algae_coldp.zip', 'w') as zipobj:
    zipobj.write('taxon.tsv')
    zipobj.write('name.tsv')
    zipobj.write('synonym.tsv')
    zipobj.write('namerelation.tsv')
    zipobj.write('reference.tsv')

os.chdir('/home/niels/code/jupyter-notebooks/nsl_export')
